# %% [markdown]
# <a href="https://colab.research.google.com/github/ElReyDeLasRefe/Plan-de-mejoramiento/blob/main/EliasDiazAsafata.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
import numpy as np
nombre = []
print("Cuantos jugadores son ?")
jugadores = int(input())
Posicion_de_jugadores = []
Casillas = ()


for x in range(jugadores):
  print("Cual es el nombre del jugador ?")
  Temporal = input("")
  nombre.append(Temporal)
  Posicion_de_jugadores.append(0)

  print(jugadores)
  print(nombre)


target_value = 45
all_match = all(x == target_value for x in Posicion_de_jugadores)
print(all_match) # Output: True
# DADOS

while Posicion_de_jugadores[x] < 46:
  if Posicion_de_jugadores[x] > 45:
    Posicion_de_jugadores[x] = Posicion_de_jugadores[x] + (45 - Posicion_de_jugadores[x])
  else:
    for x in range(jugadores):
      print(f"porfavor que siga el jugador {nombre[x]}")
      input("listo ?")
      Dice = random.randint(1, 6)
      print(f"el dado del jugador {nombre[x]} es {Dice}")
      Posicion_de_jugadores[x] += Dice
      print(f"ahora el lugar de {nombre[x]} es {Posicion_de_jugadores[x]}")


      if Posicion_de_jugadores[x] < 46:
        match Posicion_de_jugadores[x]:

          case 8:
            print(f"lo siento jugador {nombre[x]}, acabas de sufrir un corto circuito")
            Posicion_de_jugadores[x] = 0
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]}, te vas pal principio ")
          case 11:
            print(f"oyes los engranajes moverse ?, felicidades tuviste un aumento de torque")
            Posicion_de_jugadores[x] += 2
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]} ")
          case 13:
            print(f"otra vez hemos sufrido un cambio de corriente, creoque vamos a restablecer el sistema")
            Posicion_de_jugadores[x] += 12
            while i <= (jugadores):
              i += 1
              Posicion_de_jugadores[i] += (-6)
          case 15:
            print(f"con el afan de no sufrir una falla cronica, vamos a realizar un mantenimiento preventivo")
            while i <= (jugadores):
              i += 1
              Posicion_de_jugadores[i] += -2
            print(f"todos los jugadores porfavor comprendan que vamos a retroceder dos casillas")
          case 17:
            print(f"haz sufrido una falla de motor, lastimosamente")
            Posicion_de_jugadores[x] += -3
            print(f"{nombre[x]} tu nueva posicion es {Posicion_de_jugadores[x]} ")
          case 21:
            print(f"haz sufrido una actualizacion de software {nombre[x]}, avanza hasta la casilla 35")
            Posicion_de_jugadores[x] = (35)

          case 25:
            print(f"el siguiente jugador, lastimosamente no va a poder participar")


          case 28:
            print(f"oyes los engranajes moverse ?, felicidades tuviste un aumento de torque")
            Posicion_de_jugadores[x] += 2
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]} ")
          case 30:
            print(f"lo siento jugador {nombre[x]}, acabas de sufrir una falla mecanica critica")
            Posicion_de_jugadores[x] = 14
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]}, te vas para detras ")
          case 33:
            print(f"lo siento jugador {nombre[x]}, acabas de sufrir un corto circuito")
            Posicion_de_jugadores[x] = 0
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]}, te vas pal principio ")
          case 35:
            print(f"haz sufrido una actualizacion de software {nombre[x]}, retrocede hasta la casilla 21")
            Posicion_de_jugadores[x] = (21)
          case 41:
            print(f"para optimizar el sistema, debemos de tomar una decision cronica \n {nombre[x]} decide usted moverse 3 casillas o retroceder 2 casillas ?")
            casillaespecial = int(input("porfavor digite un numero entre 3 y 2"))
            if casillaespecial == 3:
              Posicion_de_jugadores[x] += 3
              print(f"tu nueva posicion es {Posicion_de_jugadores[x]} ")
            else :
              Posicion_de_jugadores[x] += -2
              print(f"tu nueva posicion es {Posicion_de_jugadores[x]} ")
          case 43:
            print(f"Lo siento {nombre[x]}")
            Posicion_de_jugadores[x] = (6)
            print(f"tu nueva posicion es {Posicion_de_jugadores[x]} ")
          case 45:
            print(f"felicidades {nombre[x]}, has ganado el juego")
  #####




tablero =  np.array([["🟩",1,"🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩"],["🟩",2,"🟩","🟩",30,29,28,27,"🟩","🟩","🟩"],["🟩",3,"🟩","🟩",31,"🟩","🟩",26,"🟩","🟩","🟩"],["🟩",4,"🟩","🟩",32,"🟩","🟩",25,"🟩","🟩","🟩"],["🟩",5,"🟩","🟩",33,34,35,36,37,38,39],["🟩",6,"🟩","🟩","🟩","🟩",24,"🟩","🟩","🟩",40],["🟩",7,"🟩","🟩","🟩","🟩",23,"🟩",45,"🟩",41],["🟩",8,"🟩",14,15,16,"🟩",22,"🟩",44,43,],["🟩",9,"🟩",13,"🟩",17,"🟩",21,"🟩","🟩","🟩"],["🟩",10,11,12,"🟩",18,19,20,"🟩","🟩","🟩"],["🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩"]])
print(tablero)

partes_v = np.vsplit(tablero,11)
# Out:
# Cuantos jugadores son ?
# 2
# Cual es el nombre del jugador ?
# e
# 2
# ['e']
# Cual es el nombre del jugador ?
# a
# 2
# ['e', 'a']
# False
# porfavor que siga el jugador e
# listo ?
# el dado del jugador e es 4
# ahora el lugar de e es 4
# porfavor que siga el jugador a
# listo ?
# el dado del jugador a es 2
# ahora el lugar de a es 2
# porfavor que siga el jugador e
# listo ?
# el dado del jugador e es 5
# ahora el lugar de e es 9
# porfavor que siga el jugador a
# listo ?
# el dado del jugador a es 5
# ahora el lugar de a es 7
# porfavor que siga el jugador e
# listo ?
# el dado del jugador e es 1
# ahora el lugar de e es 10
# porfavor que siga el jugador a
# listo ?
# el dado del jugador a es 4
# ahora el lugar de a es 11
# oyes los engranajes moverse ?, felicidades tuviste un aumento de torque
# tu nueva posicion es 13
# porfavor que siga el jugador e
# listo ?
# el dado del jugador e es 6
# ahora el lugar de e es 16
# porfavor que siga el jugador a
# listo ?
# ...

# %%
import random
import numpy as np
nombre = []
print("Cuantos jugadores son ?")
jugadores = int(input())
Posicion_de_jugadores = []
Casillas = ()


for x in range(jugadores):
  print("Cual es el nombre del jugador ?")
  Temporal = input("Please enter an item to add to the list: ")
  nombre.append(Temporal)
  Posicion_de_jugadores.append(0)

  print(jugadores)
  print(nombre)


print(f"el dado del jugador {nombre[x]} es {Posicion_de_jugadores[x]}")

# DADOS
  for x in range(jugadores):
    print(f"porfavor que siga el jugador {nombre[x]}")
    Dice = random.randint(1, 6)
    print(f"el dado del jugador {nombre[x]} es {Dice}")
    Posicion_de_jugadores[x] += Dice





  tablero =  np.array([["🟩",1,"🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩"],["🟩",2,"🟩","🟩",30,29,28,27,"🟩","🟩","🟩"],["🟩",3,"🟩","🟩",31,"🟩","🟩",26,"🟩","🟩","🟩"],["🟩",4,"🟩","🟩",32,"🟩","🟩",25,"🟩","🟩","🟩"],["🟩",5,"🟩","🟩",33,34,35,36,37,38,39],["🟩",6,"🟩","🟩","🟩","🟩",24,"🟩","🟩","🟩",40],["🟩",7,"🟩","🟩","🟩","🟩",23,"🟩",45,"🟩",41],["🟩",8,"🟩",14,15,16,"🟩",22,"🟩",44,43,],["🟩",9,"🟩",13,"🟩",17,"🟩",21,"🟩","🟩","🟩"],["🟩",10,11,12,"🟩",18,19,20,"🟩","🟩","🟩"],["🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩","🟩"]])
  print(tablero)

  partes_v = np.vsplit(tablero,11)
# Out:
# Cuantos jugadores son ?
# 2
# Cual es el nombre del jugador ?
# Please enter an item to add to the list: ek
# 2
# ['ek']
# porfavor que siga el jugador ek
# el dado del jugador ek es 6
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipython-input-4077426441.py in <cell line: 0>()
#      21 # DADOS
#      22   for x in range(jugadores):
# ---> 23     print(f"porfavor que siga el jugador {nombre[x]}")
#      24     Dice = random.randint(1, 6)
#      25     print(f"el dado del jugador {nombre[x]} es {Dice}")
#
# IndexError: list index out of range

# %%
for x in range(11):
  print(tablero[0][x])

for x in range(11):
  print(tablero[1][x])

for x in range(11):
  print(tablero[2][x])

adj = ["red", "big", "tasty"]
fruits = ["apple", "banana", "cherry"]

for x in adj:
  for y in fruits:
    print(x, y)

# %%
# Initialize an empty list
my_list = []

# Get input from the user
item_to_add = input("Please enter an item to add to the list: ")

# Add the item to the list
my_list.append(item_to_add)

# Print the updated list
print("Your updated list is:", my_list)

# Example with type conversion for numbers
num_str = input("Enter a number to add: ")
try:
    num_int = int(num_str)  # Convert to integer
    my_list.append(num_int)
except ValueError:
    print("Invalid input. Please enter a number.")

print("Your list after adding a number (if valid):", my_list)
# Out:
# Please enter an item to add to the list: 23
# Your updated list is: ['23']
# Enter a number to add: 45
# Your list after adding a number (if valid): ['23', 45]
